# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Data Flow

# %% [markdown]
# ![Imgur](http://i.imgur.com/W5hfGVo.png)
#
# Mining data directly from GitHub, `Viz` is powered by the [GitHub API](https://developer.github.com/v3/) and leverages the following:
#
# * [`github3.py`](https://github.com/sigmavirus24/github3.py) to access the GitHub API through Python.
# * [`pandas`](https://github.com/pydata/pandas) in the following [IPython Notebook](https://github.com/donnemartin/viz/blob/master/githubstats/data_wrangling.ipynb) for data wrangling.
# * [Google Maps API](https://developers.google.com/maps/?hl=en) through [`geocoder`](https://github.com/DenisCarriere/geocoder) for location data.
# * [Tableau Public](https://public.tableau.com/s/) for visualizations.*
#
# In the future, [Google BigQuery](https://cloud.google.com/bigquery/) along with [GitHub Archive](https://www.githubarchive.org/) could also supplement the GitHub API.

# %% [markdown]
# ## Imports

# %%
import re

import pandas as pd

# %% [markdown]
# ## Prepare Repo Data

# %% [markdown]
# Load the repos data and drop duplicates:

# %%
repos = pd.read_csv("data/2017/repos-dump.csv", quotechar='"', skipinitialspace=True)
print('Shape before dropping duplicates', repos.shape)
repos = repos.drop_duplicates(subset='full_name', keep='last')
print('Shape after  dropping duplicates', repos.shape)
repos.head()
# Out:
# Shape before dropping duplicates (8697, 5)
# Shape after  dropping duplicates (8697, 5)
#                           full_name  stars  forks  \
# 0  thedaviddias/Front-End-Checklist  24267   2058
# 1            GoogleChrome/puppeteer  21976   1259
# 2             parcel-bundler/parcel  13981    463
# 3   Chalarangelo/30-seconds-of-code  13466   1185
# 4      wearehive/project-guidelines  11279    970
#
#                                          description    language
# 0  🗂 The perfect Front-End Checklist for modern w...  JavaScript
# 1                           Headless Chrome Node API  JavaScript
# 2  📦🚀 Blazing fast, zero configuration web applic...  JavaScript
# 3  Curated collection of useful Javascript snippe...  JavaScript
# 4    A set of best practices for JavaScript projects  JavaScript

# %% [markdown]
# Separate out the `user` and `repo` from `full_name` into new columns:

# %%
def extract_user(line):
    return line.split('/')[0]

def extract_repo(line):
    return line.split('/')[1]

repos['user'] = repos['full_name'].str[:].apply(extract_user)
repos['repo'] = repos['full_name'].str[:].apply(extract_repo)
print(repos.shape)
repos.head()
# Out:
# (8697, 7)
#                           full_name  stars  forks  \
# 0  thedaviddias/Front-End-Checklist  24267   2058
# 1            GoogleChrome/puppeteer  21976   1259
# 2             parcel-bundler/parcel  13981    463
# 3   Chalarangelo/30-seconds-of-code  13466   1185
# 4      wearehive/project-guidelines  11279    970
#
#                                          description    language  \
# 0  🗂 The perfect Front-End Checklist for modern w...  JavaScript
# 1                           Headless Chrome Node API  JavaScript
# 2  📦🚀 Blazing fast, zero configuration web applic...  JavaScript
# 3  Curated collection of useful Javascript snippe...  JavaScript
# 4    A set of best practices for JavaScript projects  JavaScript
#
#              user                 repo
# 0    thedaviddias  Front-End-Checklist
# 1    GoogleChrome            puppeteer
# 2  parcel-bundler               parcel
# 3    Chalarangelo   30-seconds-of-code
# 4       wearehive   project-guidelines

# %% [markdown]
# ## Prepare User Data

# %% [markdown]
# Load the users data and drop duplicates:

# %%
users = pd.read_csv("data/2017/user-geocodes-dump.csv", quotechar='"', skipinitialspace=True)
print('Shape before dropping duplicates', users.shape)
users = users.drop_duplicates(subset='id', keep='last')
print('Shape after  dropping duplicates', users.shape)
users.head()
# Out:
# Shape before dropping duplicates (6426, 8)
# Shape after  dropping duplicates (6426, 8)
#                id             name          type      location        lat  \
# 0  dns-violations              NaN  Organization           NaN        NaN
# 1          hannob       Hanno Böck          User        Berlin  52.520007
# 2        takecian   Takeshi Fujiki          User  Tokyo, Japan  35.689487
# 3   jtomschroeder    Tom Schroeder          User       Chicago  41.878114
# 4       wapiflapi  Wannes Rombouts          User        France  46.227638
#
#          long     city        country
# 0         NaN      NaN            NaN
# 1   13.404954   Berlin        Germany
# 2  139.691706    Tokyo          Japan
# 3  -87.629798  Chicago  United States
# 4    2.213749      NaN         France

# %% [markdown]
# Rename column `id` to `user`:

# %%
users.rename(columns={'id': 'user'}, inplace=True)
users.head()
# Out:
#              user             name          type      location        lat  \
# 0  dns-violations              NaN  Organization           NaN        NaN
# 1          hannob       Hanno Böck          User        Berlin  52.520007
# 2        takecian   Takeshi Fujiki          User  Tokyo, Japan  35.689487
# 3   jtomschroeder    Tom Schroeder          User       Chicago  41.878114
# 4       wapiflapi  Wannes Rombouts          User        France  46.227638
#
#          long     city        country
# 0         NaN      NaN            NaN
# 1   13.404954   Berlin        Germany
# 2  139.691706    Tokyo          Japan
# 3  -87.629798  Chicago  United States
# 4    2.213749      NaN         France

# %% [markdown]
# ## Merge Repo and User Data

# %% [markdown]
# Left join repos and users:

# %%
repos_users = pd.merge(repos, users, on='user', how='left')
print('Shape repos:', repos.shape)
print('Shape users:', users.shape)
print('Shape repos_users:', repos_users.shape)
repos_users.head()
# Out:
# Shape repos: (8697, 7)
# Shape users: (6426, 8)
# Shape repos_users: (8697, 14)
#                           full_name  stars  forks  \
# 0  thedaviddias/Front-End-Checklist  24267   2058
# 1            GoogleChrome/puppeteer  21976   1259
# 2             parcel-bundler/parcel  13981    463
# 3   Chalarangelo/30-seconds-of-code  13466   1185
# 4      wearehive/project-guidelines  11279    970
#
#                                          description    language  \
# 0  🗂 The perfect Front-End Checklist for modern w...  JavaScript
# 1                           Headless Chrome Node API  JavaScript
# 2  📦🚀 Blazing fast, zero configuration web applic...  JavaScript
# 3  Curated collection of useful Javascript snippe...  JavaScript
# 4    A set of best practices for JavaScript projects  JavaScript
#
#              user                 repo              name          type  \
# 0    thedaviddias  Front-End-Checklist        David Dias          User
# 1    GoogleChrome            puppeteer               NaN  Organization
# 2  parcel-bundler               parcel            Parcel  Organization
# 3    Chalarangelo   30-seconds-of-code  Angelos Chalaris          User
# 4       wearehive   project-guidelines              Hive  Organization
#
#                     location        lat       long    city         country
# 0  France, Mauritius, Canada        NaN        NaN     NaN             NaN
# 1                        NaN        NaN        NaN     NaN             NaN
# 2                        NaN        NaN        NaN     NaN             NaN
# 3             Athens, Greece  37.983810  23.727539  Athens          Greece
# 4                     London  51.507351  -0.127758  London  United Kingdom

# %% [markdown]
# ## Tidy Up Repo and User Data

# %% [markdown]
# Re-order the columns:

# %%
repos_users = repos_users.reindex_axis(['full_name',
                                        'repo',
                                        'description',
                                        'stars',
                                        'forks',
                                        'language',
                                        'user',
                                        'name',
                                        'type',
                                        'location',
                                        'lat',
                                        'long',
                                        'city',
                                        'country'], axis=1)
print(repos_users.shape)
repos_users.head()
# Out:
# (8697, 14)
#                           full_name                 repo  \
# 0  thedaviddias/Front-End-Checklist  Front-End-Checklist
# 1            GoogleChrome/puppeteer            puppeteer
# 2             parcel-bundler/parcel               parcel
# 3   Chalarangelo/30-seconds-of-code   30-seconds-of-code
# 4      wearehive/project-guidelines   project-guidelines
#
#                                          description  stars  forks  \
# 0  🗂 The perfect Front-End Checklist for modern w...  24267   2058
# 1                           Headless Chrome Node API  21976   1259
# 2  📦🚀 Blazing fast, zero configuration web applic...  13981    463
# 3  Curated collection of useful Javascript snippe...  13466   1185
# 4    A set of best practices for JavaScript projects  11279    970
#
#      language            user              name          type  \
# 0  JavaScript    thedaviddias        David Dias          User
# 1  JavaScript    GoogleChrome               NaN  Organization
# 2  JavaScript  parcel-bundler            Parcel  Organization
# 3  JavaScript    Chalarangelo  Angelos Chalaris          User
# 4  JavaScript       wearehive              Hive  Organization
#
#                     location        lat       long    city         country
# 0  France, Mauritius, Canada        NaN        NaN     NaN             NaN
# 1                        NaN        NaN        NaN     NaN             NaN
# 2                        NaN        NaN        NaN     NaN             NaN
# 3             Athens, Greece  37.983810  23.727539  Athens          Greece
# 4                     London  51.507351  -0.127758  London  United Kingdom

# %% [markdown]
# ## Add Overall Ranks

# %% [markdown]
# Rank each element based on number of stars:

# %%
repos_users['rank'] = repos_users['stars'].rank(ascending=False)
print(repos_users.shape)
repos_users.head()
# Out:
# (8697, 15)
#                           full_name                 repo  \
# 0  thedaviddias/Front-End-Checklist  Front-End-Checklist
# 1            GoogleChrome/puppeteer            puppeteer
# 2             parcel-bundler/parcel               parcel
# 3   Chalarangelo/30-seconds-of-code   30-seconds-of-code
# 4      wearehive/project-guidelines   project-guidelines
#
#                                          description  stars  forks  \
# 0  🗂 The perfect Front-End Checklist for modern w...  24267   2058
# 1                           Headless Chrome Node API  21976   1259
# 2  📦🚀 Blazing fast, zero configuration web applic...  13981    463
# 3  Curated collection of useful Javascript snippe...  13466   1185
# 4    A set of best practices for JavaScript projects  11279    970
#
#      language            user              name          type  \
# 0  JavaScript    thedaviddias        David Dias          User
# 1  JavaScript    GoogleChrome               NaN  Organization
# 2  JavaScript  parcel-bundler            Parcel  Organization
# 3  JavaScript    Chalarangelo  Angelos Chalaris          User
# 4  JavaScript       wearehive              Hive  Organization
#
#                     location        lat       long    city         country  \
# 0  France, Mauritius, Canada        NaN        NaN     NaN             NaN
# 1                        NaN        NaN        NaN     NaN             NaN
# 2                        NaN        NaN        NaN     NaN             NaN
# 3             Athens, Greece  37.983810  23.727539  Athens          Greece
# 4                     London  51.507351  -0.127758  London  United Kingdom
#
#    rank
# 0     3
# 1     4
# 2    11
# 3    13
# 4    16

# %% [markdown]
# ## Verify Results: Users

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2017-01-01..2017-12-31+stars%3A%3E%3D100+user%3Adonnemartin&type=Repositories&ref=searchresults): `created:2017-01-01..2017-12-31 stars:>=100 user:donnemartin`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2017.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
repos_users[repos_users['user'] == 'donnemartin']
# Out:
#                              full_name                  repo  \
# 3308  donnemartin/system-design-primer  system-design-primer
#
#                                             description  stars  forks  \
# 3308  Learn how to design large-scale systems. Prep ...  21780   2633
#
#      language         user          name  type          location        lat  \
# 3308   Python  donnemartin  Donne Martin  User  Washington, D.C.  38.907192
#
#            long        city        country  rank
# 3308 -77.036871  Washington  United States     5

# %% [markdown]
# ## Verify Results: Python Repos

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2017-01-01..2017-12-31+stars%3A%3E%3D100+language%3Apython&type=Repositories&ref=searchresults): `created:2017-01-01..2017-12-31 stars:>=100 language:python`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2017.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
print(repos_users[repos_users['language'] == 'Python'].shape)
repos_users[repos_users['language'] == 'Python'].head()
# Out:
# (1357, 15)
#                              full_name                  repo  \
# 3308  donnemartin/system-design-primer  system-design-primer
# 3309                    python/cpython               cpython
# 3310         ageitgey/face_recognition      face_recognition
# 3311          tonybeltramelli/pix2code              pix2code
# 3312                google/python-fire           python-fire
#
#                                             description  stars  forks  \
# 3308  Learn how to design large-scale systems. Prep ...  21780   2633
# 3309                    The Python programming language  15060   3779
# 3310  The world's simplest facial recognition api fo...   8487   1691
# 3311  pix2code: Generating Code from a Graphical Use...   8037    605
# 3312  Python Fire is a library for automatically gen...   7663    386
#
#      language             user              name          type  \
# 3308   Python      donnemartin      Donne Martin          User
# 3309   Python           python            Python  Organization
# 3310   Python         ageitgey      Adam Geitgey          User
# 3311   Python  tonybeltramelli  Tony Beltramelli          User
# 3312   Python           google            Google  Organization
#
#               location        lat       long        city        country  rank
# 3308  Washington, D.C.  38.907192 -77.036871  Washington  United States     5
# 3309               NaN        NaN        NaN         NaN            NaN     9
# 3310    Various places        NaN        NaN         NaN            NaN    31
# 3311           Denmark        NaN        NaN         NaN            NaN    34
# 3312               NaN        NaN        NaN         NaN            NaN    36

# %% [markdown]
# ## Verify Results: Overall Repos

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2017-01-01..2017-12-31+stars%3A%3E%3D100&type=Repositories&ref=searchresults): `created:2017-01-01..2017-12-31 stars:>=100`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2017.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
print(repos_users.shape)
repos_users.head()
# Out:
# (8697, 15)
#                           full_name                 repo  \
# 0  thedaviddias/Front-End-Checklist  Front-End-Checklist
# 1            GoogleChrome/puppeteer            puppeteer
# 2             parcel-bundler/parcel               parcel
# 3   Chalarangelo/30-seconds-of-code   30-seconds-of-code
# 4      wearehive/project-guidelines   project-guidelines
#
#                                          description  stars  forks  \
# 0  🗂 The perfect Front-End Checklist for modern w...  24267   2058
# 1                           Headless Chrome Node API  21976   1259
# 2  📦🚀 Blazing fast, zero configuration web applic...  13981    463
# 3  Curated collection of useful Javascript snippe...  13466   1185
# 4    A set of best practices for JavaScript projects  11279    970
#
#      language            user              name          type  \
# 0  JavaScript    thedaviddias        David Dias          User
# 1  JavaScript    GoogleChrome               NaN  Organization
# 2  JavaScript  parcel-bundler            Parcel  Organization
# 3  JavaScript    Chalarangelo  Angelos Chalaris          User
# 4  JavaScript       wearehive              Hive  Organization
#
#                     location        lat       long    city         country  \
# 0  France, Mauritius, Canada        NaN        NaN     NaN             NaN
# 1                        NaN        NaN        NaN     NaN             NaN
# 2                        NaN        NaN        NaN     NaN             NaN
# 3             Athens, Greece  37.983810  23.727539  Athens          Greece
# 4                     London  51.507351  -0.127758  London  United Kingdom
#
#    rank
# 0     3
# 1     4
# 2    11
# 3    13
# 4    16

# %% [markdown]
# ## Output Results

# %% [markdown]
# Write out the results to csv to visualize in Tableau:

# %%
users.to_csv('data/2017/users.csv', index=False)
repos_users.to_csv('data/2017/repos-users-geocodes.csv', index=False)
repos_users.to_csv('data/2017/repos-users.csv', index=False)

# %%
repos_rank = repos_users.reindex_axis(['full_name', 'rank'], axis=1)
repos_rank.to_csv('data/2017/repos-ranks.csv', index=False)
