# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Data Flow

# %% [markdown]
# ![Imgur](http://i.imgur.com/W5hfGVo.png)
#
# Mining data directly from GitHub, `Viz` is powered by the [GitHub API](https://developer.github.com/v3/) and leverages the following:
#
# * [`github3.py`](https://github.com/sigmavirus24/github3.py) to access the GitHub API through Python.
# * [`pandas`](https://github.com/pydata/pandas) in the following [IPython Notebook](https://github.com/donnemartin/viz/blob/master/githubstats/data_wrangling.ipynb) for data wrangling.
# * [Google Maps API](https://developers.google.com/maps/?hl=en) through [`geocoder`](https://github.com/DenisCarriere/geocoder) for location data.
# * [Tableau Public](https://public.tableau.com/s/) for visualizations.*
#
# In the future, [Google BigQuery](https://cloud.google.com/bigquery/) along with [GitHub Archive](https://www.githubarchive.org/) could also supplement the GitHub API.

# %% [markdown]
# ## Imports

# %%
import re

import pandas as pd

# %% [markdown]
# ## Prepare Repo Data

# %% [markdown]
# Load the repos data and drop duplicates:

# %%
repos = pd.read_csv("data/2016/repos-dump.csv", quotechar='"', skipinitialspace=True)
print('Shape before dropping duplicates', repos.shape)
repos = repos.drop_duplicates(subset='full_name', keep='last')
print('Shape after  dropping duplicates', repos.shape)
repos.head()
# Out:
# Shape before dropping duplicates (8043, 5)
# Shape after  dropping duplicates (8040, 5)
#                             full_name  stars  forks  \
# 0                        yarnpkg/yarn  21060    786
# 1  facebookincubator/create-react-app  17555   1821
# 2                          zeit/hyper  13618    907
# 3          ParsePlatform/parse-server  12167   3319
# 4                 juliangarnier/anime  10245    539
#
#                                          description    language
# 0  📦🐈 Fast, reliable, and secure dependency manag...  JavaScript
# 1     Create React apps with no build configuration.  JavaScript
# 2               A terminal built on web technologies  JavaScript
# 3  Parse-compatible API server module for Node/Ex...  JavaScript
# 4                        Javascript Animation Engine  JavaScript

# %% [markdown]
# Separate out the `user` and `repo` from `full_name` into new columns:

# %%
def extract_user(line):
    return line.split('/')[0]

def extract_repo(line):
    return line.split('/')[1]

repos['user'] = repos['full_name'].str[:].apply(extract_user)
repos['repo'] = repos['full_name'].str[:].apply(extract_repo)
print(repos.shape)
repos.head()
# Out:
# (8040, 7)
#                             full_name  stars  forks  \
# 0                        yarnpkg/yarn  21060    786
# 1  facebookincubator/create-react-app  17555   1821
# 2                          zeit/hyper  13618    907
# 3          ParsePlatform/parse-server  12167   3319
# 4                 juliangarnier/anime  10245    539
#
#                                          description    language  \
# 0  📦🐈 Fast, reliable, and secure dependency manag...  JavaScript
# 1     Create React apps with no build configuration.  JavaScript
# 2               A terminal built on web technologies  JavaScript
# 3  Parse-compatible API server module for Node/Ex...  JavaScript
# 4                        Javascript Animation Engine  JavaScript
#
#                 user              repo
# 0            yarnpkg              yarn
# 1  facebookincubator  create-react-app
# 2               zeit             hyper
# 3      ParsePlatform      parse-server
# 4      juliangarnier             anime

# %% [markdown]
# ## Prepare User Data

# %% [markdown]
# Load the users data and drop duplicates:

# %%
users = pd.read_csv("data/2016/user-geocodes-dump.csv", quotechar='"', skipinitialspace=True)
print('Shape before dropping duplicates', users.shape)
users = users.drop_duplicates(subset='id', keep='last')
print('Shape after  dropping duplicates', users.shape)
users.head()
# Out:
# Shape before dropping duplicates (5991, 8)
# Shape after  dropping duplicates (5991, 8)
#             id                       name          type              location  \
# 0     symentis              symentis GmbH  Organization  Unterhaching, Munich
# 1      voghDev              Olmo Gallegos          User               Granada
# 2   wxyyxc1992           王下邀月熊(Chevalier)          User               NanJing
# 3    vermont42                 Josh Adams          User  Berkeley, California
# 4  mjosaarinen  Markku-Juhani O. Saarinen          User                   NaN
#
#          lat        long          city        country
# 0  48.068918   11.621253  Unterhaching        Germany
# 1  37.177336   -3.598557       Granada          Spain
# 2  32.060255  118.796877       Nanjing          China
# 3  37.871593 -122.272747      Berkeley  United States
# 4        NaN         NaN           NaN            NaN

# %% [markdown]
# Rename column `id` to `user`:

# %%
users.rename(columns={'id': 'user'}, inplace=True)
users.head()
# Out:
#           user                       name          type              location  \
# 0     symentis              symentis GmbH  Organization  Unterhaching, Munich
# 1      voghDev              Olmo Gallegos          User               Granada
# 2   wxyyxc1992           王下邀月熊(Chevalier)          User               NanJing
# 3    vermont42                 Josh Adams          User  Berkeley, California
# 4  mjosaarinen  Markku-Juhani O. Saarinen          User                   NaN
#
#          lat        long          city        country
# 0  48.068918   11.621253  Unterhaching        Germany
# 1  37.177336   -3.598557       Granada          Spain
# 2  32.060255  118.796877       Nanjing          China
# 3  37.871593 -122.272747      Berkeley  United States
# 4        NaN         NaN           NaN            NaN

# %% [markdown]
# ## Merge Repo and User Data

# %% [markdown]
# Left join repos and users:

# %%
repos_users = pd.merge(repos, users, on='user', how='left')
print('Shape repos:', repos.shape)
print('Shape users:', users.shape)
print('Shape repos_users:', repos_users.shape)
repos_users.head()
# Out:
# Shape repos: (8040, 7)
# Shape users: (5991, 8)
# Shape repos_users: (8040, 14)
#                             full_name  stars  forks  \
# 0                        yarnpkg/yarn  21060    786
# 1  facebookincubator/create-react-app  17555   1821
# 2                          zeit/hyper  13618    907
# 3          ParsePlatform/parse-server  12167   3319
# 4                 juliangarnier/anime  10245    539
#
#                                          description    language  \
# 0  📦🐈 Fast, reliable, and secure dependency manag...  JavaScript
# 1     Create React apps with no build configuration.  JavaScript
# 2               A terminal built on web technologies  JavaScript
# 3  Parse-compatible API server module for Node/Ex...  JavaScript
# 4                        Javascript Animation Engine  JavaScript
#
#                 user              repo                name          type  \
# 0            yarnpkg              yarn                Yarn  Organization
# 1  facebookincubator  create-react-app  Facebook Incubator  Organization
# 2               zeit             hyper                ZEIT  Organization
# 3      ParsePlatform      parse-server               Parse  Organization
# 4      juliangarnier             anime      Julian Garnier          User
#
#                  location        lat        long        city        country
# 0                     NaN        NaN         NaN         NaN            NaN
# 1  Menlo Park, California  37.452960 -122.181725  Menlo Park  United States
# 2                     NaN        NaN         NaN         NaN            NaN
# 3          Menlo Park, CA  37.452960 -122.181725  Menlo Park  United States
# 4                   Paris  48.856614    2.352222       Paris         France

# %% [markdown]
# ## Tidy Up Repo and User Data

# %% [markdown]
# Re-order the columns:

# %%
repos_users = repos_users.reindex_axis(['full_name',
                                        'repo',
                                        'description',
                                        'stars',
                                        'forks',
                                        'language',
                                        'user',
                                        'name',
                                        'type',
                                        'location',
                                        'lat',
                                        'long',
                                        'city',
                                        'country'], axis=1)
print(repos_users.shape)
repos_users.head()
# Out:
# (8040, 14)
#                             full_name              repo  \
# 0                        yarnpkg/yarn              yarn
# 1  facebookincubator/create-react-app  create-react-app
# 2                          zeit/hyper             hyper
# 3          ParsePlatform/parse-server      parse-server
# 4                 juliangarnier/anime             anime
#
#                                          description  stars  forks  \
# 0  📦🐈 Fast, reliable, and secure dependency manag...  21060    786
# 1     Create React apps with no build configuration.  17555   1821
# 2               A terminal built on web technologies  13618    907
# 3  Parse-compatible API server module for Node/Ex...  12167   3319
# 4                        Javascript Animation Engine  10245    539
#
#      language               user                name          type  \
# 0  JavaScript            yarnpkg                Yarn  Organization
# 1  JavaScript  facebookincubator  Facebook Incubator  Organization
# 2  JavaScript               zeit                ZEIT  Organization
# 3  JavaScript      ParsePlatform               Parse  Organization
# 4  JavaScript      juliangarnier      Julian Garnier          User
#
#                  location        lat        long        city        country
# 0                     NaN        NaN         NaN         NaN            NaN
# 1  Menlo Park, California  37.452960 -122.181725  Menlo Park  United States
# 2                     NaN        NaN         NaN         NaN            NaN
# 3          Menlo Park, CA  37.452960 -122.181725  Menlo Park  United States
# 4                   Paris  48.856614    2.352222       Paris         France

# %% [markdown]
# ## Add Overall Ranks

# %% [markdown]
# Rank each element based on number of stars:

# %%
repos_users['rank'] = repos_users['stars'].rank(ascending=False)
print(repos_users.shape)
repos_users.head()
# Out:
# (8040, 15)
#                             full_name              repo  \
# 0                        yarnpkg/yarn              yarn
# 1  facebookincubator/create-react-app  create-react-app
# 2                          zeit/hyper             hyper
# 3          ParsePlatform/parse-server      parse-server
# 4                 juliangarnier/anime             anime
#
#                                          description  stars  forks  \
# 0  📦🐈 Fast, reliable, and secure dependency manag...  21060    786
# 1     Create React apps with no build configuration.  17555   1821
# 2               A terminal built on web technologies  13618    907
# 3  Parse-compatible API server module for Node/Ex...  12167   3319
# 4                        Javascript Animation Engine  10245    539
#
#      language               user                name          type  \
# 0  JavaScript            yarnpkg                Yarn  Organization
# 1  JavaScript  facebookincubator  Facebook Incubator  Organization
# 2  JavaScript               zeit                ZEIT  Organization
# 3  JavaScript      ParsePlatform               Parse  Organization
# 4  JavaScript      juliangarnier      Julian Garnier          User
#
#                  location        lat        long        city        country  \
# 0                     NaN        NaN         NaN         NaN            NaN
# 1  Menlo Park, California  37.452960 -122.181725  Menlo Park  United States
# 2                     NaN        NaN         NaN         NaN            NaN
# 3          Menlo Park, CA  37.452960 -122.181725  Menlo Park  United States
# 4                   Paris  48.856614    2.352222       Paris         France
#
#    rank
# 0     2
# 1     4
# 2     8
# 3     9
# 4    16

# %% [markdown]
# ## Verify Results: Users

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2016-01-01..2016-12-31+stars%3A%3E%3D100+user%3Adonnemartin&type=Repositories&ref=searchresults): `created:2016-01-01..2016-12-31 stars:>=100 user:donnemartin`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2016.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
repos_users[repos_users['user'] == 'donnemartin']
# Out:
#                 full_name     repo  \
# 3692  donnemartin/gitsome  gitsome
# 3890      donnemartin/viz      viz
#
#                                             description  stars  forks  \
# 3692  A supercharged Git/GitHub command line interfa...   4482    158
# 3890  GitHub's most popular repos, interactively vis...    359     27
#
#      language         user          name  type          location        lat  \
# 3692   Python  donnemartin  Donne Martin  User  Washington, D.C.  38.907192
# 3890   Python  donnemartin  Donne Martin  User  Washington, D.C.  38.907192
#
#            long        city        country    rank
# 3692 -77.036871  Washington  United States    89.5
# 3890 -77.036871  Washington  United States  2521.0

# %% [markdown]
# ## Verify Results: Python Repos

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2016-01-01..2016-12-31+stars%3A%3E%3D100+language%3Apython&type=Repositories&ref=searchresults): `created:2016-01-01..2016-12-31 stars:>=100 language:python`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2016.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
print(repos_users[repos_users['language'] == 'Python'].shape)
repos_users[repos_users['language'] == 'Python'].head()
# Out:
# (866, 15)
#                                            full_name  \
# 3681                               tensorflow/models
# 3682  songrotek/Deep-Learning-Papers-Reading-Roadmap
# 3683                        Rochester-NRT/RocAlphaGo
# 3684                            alexjc/neural-doodle
# 3685                                     p-e-w/maybe
#
#                                       repo  \
# 3681                                models
# 3682  Deep-Learning-Papers-Reading-Roadmap
# 3683                            RocAlphaGo
# 3684                         neural-doodle
# 3685                                 maybe
#
#                                             description  stars  forks  \
# 3681                       Models built with TensorFlow  10336   2707
# 3682  Deep Learning papers reading roadmap for anyon...   8707   1123
# 3683  An independent, student-led replication of Dee...   7597   2111
# 3684  Turn your two-bit doodles into fine artworks w...   7226    514
# 3685   :open_file_folder: :rabbit2: :tophat: See wha...   6078    162
#
#      language           user                      name          type  \
# 3681   Python     tensorflow                       NaN  Organization
# 3682   Python      songrotek                Flood Sung          User
# 3683   Python  Rochester-NRT                       NaN  Organization
# 3684   Python         alexjc       Alex J. Champandard          User
# 3685   Python          p-e-w  Philipp Emanuel Weidmann          User
#
#                       location        lat        long    city  country  rank
# 3681                       NaN        NaN         NaN     NaN      NaN    15
# 3682                     China  35.861660  104.195397     NaN    China    23
# 3683                       NaN        NaN         NaN     NaN      NaN    35
# 3684           Vienna, Austria  48.208174   16.373819  Vienna  Austria    38
# 3685  Anywhere the Internet is        NaN         NaN     NaN      NaN    52

# %% [markdown]
# ## Verify Results: Overall Repos

# %% [markdown]
# Equivalent [GitHub search query](https://github.com/search?utf8=%E2%9C%93&q=created%3A2016-01-01..2016-12-31+stars%3A%3E%3D100&type=Repositories&ref=searchresults): `created:2016-01-01..2016-12-31 stars:>=100`
#
# *Note: The data might be slightly off, as the search query will take into account data up to when the query was executed.  Data in this notebook was mined on January 1, 2017 to 'freeze' the results for the year 2016.  The longer you run the search from January 1, 2017, the larger the discrepancy.*

# %%
print(repos_users.shape)
repos_users.head()
# Out:
# (8040, 15)
#                             full_name              repo  \
# 0                        yarnpkg/yarn              yarn
# 1  facebookincubator/create-react-app  create-react-app
# 2                          zeit/hyper             hyper
# 3          ParsePlatform/parse-server      parse-server
# 4                 juliangarnier/anime             anime
#
#                                          description  stars  forks  \
# 0  📦🐈 Fast, reliable, and secure dependency manag...  21060    786
# 1     Create React apps with no build configuration.  17555   1821
# 2               A terminal built on web technologies  13618    907
# 3  Parse-compatible API server module for Node/Ex...  12167   3319
# 4                        Javascript Animation Engine  10245    539
#
#      language               user                name          type  \
# 0  JavaScript            yarnpkg                Yarn  Organization
# 1  JavaScript  facebookincubator  Facebook Incubator  Organization
# 2  JavaScript               zeit                ZEIT  Organization
# 3  JavaScript      ParsePlatform               Parse  Organization
# 4  JavaScript      juliangarnier      Julian Garnier          User
#
#                  location        lat        long        city        country  \
# 0                     NaN        NaN         NaN         NaN            NaN
# 1  Menlo Park, California  37.452960 -122.181725  Menlo Park  United States
# 2                     NaN        NaN         NaN         NaN            NaN
# 3          Menlo Park, CA  37.452960 -122.181725  Menlo Park  United States
# 4                   Paris  48.856614    2.352222       Paris         France
#
#    rank
# 0     2
# 1     4
# 2     8
# 3     9
# 4    16

# %% [markdown]
# ## Output Results

# %% [markdown]
# Write out the results to csv to visualize in Tableau:

# %%
users.to_csv('data/2016/users.csv', index=False)
repos_users.to_csv('data/2016/repos-users-geocodes.csv', index=False)
repos_users.to_csv('data/2016/repos-users.csv', index=False)

# %%
repos_rank = repos_users.reindex_axis(['full_name', 'rank'], axis=1)
repos_rank.to_csv('data/2016/repos-ranks.csv', index=False)
